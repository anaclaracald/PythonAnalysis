# %%
data = [50, 57, 62, 45, 70, 55, 60, 65, 75, 80]
print(data)
# Out:
# [50, 57, 62, 45, 70, 55, 60, 65, 75, 80]

# %%
import numpy as np

grades = np.array([50, 57, 62, 45, 70, 55, 60, 65, 75, 80, 90, 85, 95, 100, 40, 30, 20, 10, 0, 77, 88, 99])
print(grades)
# Out:
# [ 50  57  62  45  70  55  60  65  75  80  90  85  95 100  40  30  20  10
#    0  77  88  99]

# %%
grades.shape
# Out:
# (22,)

# %%
grades_mean = np.mean(grades)
print("Mean:", grades_mean)
# Out:
# Mean: 61.5

# %%
study_hours = np.array([10.0,11.5,9.0,16.0,9.25,1.0,11.5,9.0,8.5,14.5, 15.5,
13.75,9.0,8.0,15.5,8.0,9.0,6.0,10.0,12.0,12.5,12.0])
study_hours.shape
# Out:
# (22,)

# %%
import pandas as pd

students = ["Maria", "John", "Lily", "David", "Sophia", "James", "Olivia", "Michael", "Emma", "Daniel",
            "Ava", "Ethan", "Isabella", "Alexander", "Mia", "Benjamin", "Charlotte", "Elijah", "Amelia", "Lucas", "Harper", "Henry"]

studentFrame = pd.DataFrame({'Name': students,'Grades': grades, 'Study Hours': study_hours})

print(studentFrame)
# Out:
#          Name  Grades  Study Hours
# 0       Maria      50        10.00
# 1        John      57        11.50
# 2        Lily      62         9.00
# 3       David      45        16.00
# 4      Sophia      70         9.25
# 5       James      55         1.00
# 6      Olivia      60        11.50
# 7     Michael      65         9.00
# 8        Emma      75         8.50
# 9      Daniel      80        14.50
# 10        Ava      90        15.50
# 11      Ethan      85        13.75
# 12   Isabella      95         9.00
# 13  Alexander     100         8.00
# 14        Mia      40        15.50
# 15   Benjamin      30         8.00
# 16  Charlotte      20         9.00
# 17     Elijah      10         6.00
# 18     Amelia       0        10.00
# 19      Lucas      77        12.00
# 20     Harper      88        12.50
# 21      Henry      99        12.00
